# %% [markdown]
# # Colorectal Histology
#
# #### Gökay Berkem TURAN
# #### Zafer Can YÜCEL
#
# In this project, we will make a classification using a [Colorectal Histology MNIST Dataset](https://www.kaggle.com/kmader/colorectal-histology-mnist) consisting of 8 different types of tissues taken from colorectal cancer patients. We will use deep learning models to make this classification. We will make classification with four different CNN models and compare their results. We will calculate accuracy using the ratio of correct predictions to total predictions to evaluate the success of the classification.

# %% [markdown]
# ## Table of Content
#
# [Problem](#problem)
# [Data Understanding](#data_understanding)
# [Data Preparation](#data_preparation)
# [Modeling](#modeling)
# [Evaluation](#evaluation)
# [References](#references)

# %% [markdown]
# ## Problem <a class="anchor" id="problem"></a>

# %% [markdown]
# Although the images used in pathological examinations are high-resolution images, problems arise in the classification of tissues by humans because the tissues are micro-sized. Since such issues are directly related to human health, the diagnosis process of the disease should be more precise. Therefore, it is necessary to increase the accuracy of the diagnosis of the disease.  We will use deep learning models to eliminate these problems and facilitate the classification of tissues.

# %% [markdown]
# ## Data Understanding<a class="anchor" id="data_understanding"></a>

# %% [markdown]
# In this project, we are using the [Colorectal Histology MNIST Dataset](https://www.kaggle.com/kmader/colorectal-histology-mnist). This dataset is a dataset consisting of 8 classes (TUMOR, STROMA, COMPLEX, LYMPHO, DEBRIS, MUCOSA, ADIPOSE, EMPTY) and 5000 images. The image resolution in the dataset is 150x150 pixels. Class distribution in the dataset is equal. There are 625 images in each class. All images in the dataset are in RGB format.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import torch.utils.data
import time
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from torchvision.datasets import ImageFolder
from torch.optim import lr_scheduler
from torchvision.transforms import transforms
from torchvision import transforms, models
import warnings
import seaborn as sns
import matplotlib.pyplot as pltt
import pandas as pd
import cv2
from PIL import Image
warnings.filterwarnings("ignore")
#  Device config
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print("Device: ", device)
print(torch.cuda.get_device_name(0))
# Out:
# Device:  cuda:0
# Tesla T4

# %% [markdown]
# ## Data Preparation<a class="anchor" id="data_preparation"></a>

# %% [markdown]
# We converted the images in our dataset from tif format to jpg format. We split our dataset into 70% train, 15% test and 15% validation. You can access the split version of the dataset from the [link here](https://drive.google.com/drive/folders/1Y1IlZ4Tkuf72R3p1ydmfnSgb1mLs6wSc). Our dataset includes 3512 train, 744 test and 744 validation images. Each class has 439 train, 93 test and 93 validation images. We used train data while training our model, we used validation data while setting the hyperparameters of our models. While testing our model with unseen data, we measured the success of our model using test data. Since our dataset does not contain too many images, it is possible for our model to learn the detail and noise in the training data and this situation causes overfitting. We need to diversify the data we have in order to prevent overfitting and increase accuracy. If we do not have enough data, we can do data diversification by using data augmentation method. We used the class "transforms" in the PyTorch library to do data augmentation. We used data augmentation only for train data. For the train data, we resized the images to 224x224, applied random horizontal flip, random vertical flip, random rotation, and normalized the images. For test and validation data, we resized the images to be 224x224 - the input size of the CNN models we use - and normalized the images.

# %%
transformed = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

transformations_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.RandomVerticalFlip(p = 0.5),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
fig, ax = plt.subplots(1,4, figsize= (20,5))
image = Image.open('/content/drive/MyDrive/BBM469-Project/Dataset_469/train/07_ADIPOSE/12B5F_CRC-Prim-HE-05_032.jpg')
ax[0].imshow(image)
ax[0].set_title('Original', fontsize = 10)
ax[0].get_xaxis().set_visible(False)
ax[0].get_yaxis().set_visible(False)

ax[1].imshow(transforms.functional.hflip(image))
ax[1].set_title('Horizontal Flip', fontsize = 10)
ax[1].get_xaxis().set_visible(False)
ax[1].get_yaxis().set_visible(False)

ax[2].imshow(transforms.functional.vflip(image))
ax[2].set_title('Vertical Flip', fontsize = 10)
ax[2].get_xaxis().set_visible(False)
ax[2].get_yaxis().set_visible(False)

ax[3].imshow(transforms.functional.rotate(image,15))
ax[3].set_title('Rotation', fontsize = 10)
ax[3].get_xaxis().set_visible(False)
ax[3].get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <h4>Data Loader</h4>

# %%
train_path = '/content/drive/MyDrive/BBM469-Project/Dataset_469/train'
validation_path = '/content/drive/MyDrive/BBM469-Project/Dataset_469/val'
test_path = '/content/drive/MyDrive/BBM469-Project/Dataset_469/test'

batch_size = 32

train_ = ImageFolder(root=train_path, transform=transformations_train)
validation_ = ImageFolder(root=validation_path, transform=transformed)
test_ = ImageFolder(root=test_path, transform=transformed)

trainLoader = torch.utils.data.DataLoader(train_, batch_size=batch_size, num_workers=2, shuffle=True)
validationLoader = torch.utils.data.DataLoader(validation_, batch_size=batch_size, num_workers=2, shuffle=True)
testLoader = torch.utils.data.DataLoader(test_, batch_size=batch_size, num_workers=2)

# %% [markdown]
# ## Modeling<a class="anchor" id="modeling"></a>

# %% [markdown]
# In this project, we will use the deep learning method to do the classification process. There are various deep learning models. We will compare these models using 4 of these models. We will use the transfer learning method while training these models. Transfer learning is using the weights of a previously trained model for another problem while solving a different problem. By using the transfer learning method, we save both time and resources. We can apply the transfer learning method in two different ways. The first is to use feature extraction part of the pre-trained model and modify the classification part(fully connected layer) to make model suitable for our problem by changing last fully connected layer's output size. The second is to freeze the weights of some part of the pre-trained model and train the rest. While applying the second method, it would be more accurate to freeze the first layers because the first layers of deep learning models are used to extract general features and these features can be used in many tasks. While we are applying transfer learning in our project, we freeze the layers other than the last fully connected layer and change the last fully connected layer output size as the number of classes to make model suitable for our problem.

# %% [markdown]
# We used the Stochastic Gradient Descent (SGD) optimizer as the optimizer for each of our models, and we used the Cross Entropy Loss function as the loss function. We trained our model with 100 epochs.

# %% [markdown]
# Below are the train, test functions for our models, and a function to plot loss and accuracy graph.

# %% [markdown]
# <h5>Test Function</h5>

# %%
def test(cnnNetwork, lossFunction, loader):
    with torch.no_grad():
        cnnNetwork.eval()
        correct = 0.0
        total = 0.0
        r_loss = 0.0
        for i, (images, labels) in enumerate(loader):
            images, labels = images.to(device), labels.to(device)

            outputs = cnnNetwork(images)
            loss = lossFunction(outputs, labels)
            r_loss += loss.item()
            _, prediction = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (prediction == labels).sum().item()
        avg_loss = r_loss / len(loader)

        accuracy = 100 * correct / total
        return accuracy, avg_loss

# %% [markdown]
# <h5>Train Function</h5>

# %%
def train(cnnNetwork, epoch_, lossFunction, optimizer, path):
    best_accuracy = 0
    train_accuracy_list = []
    validation_accuracy_list = []
    train_loss_list = []
    validation_loss_list = []

    for k in range(epoch_):
        cnnNetwork.train()
        total_train_loss = 0.0
        train_accuracy = 0.0
        total = 0
        for i, (input_images, labels) in enumerate(trainLoader):
            input_images, labels = input_images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = cnnNetwork(input_images)
            loss = lossFunction(outputs, labels)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()
            _, prediction = torch.max(outputs.data, 1)
            train_accuracy += (prediction == labels).sum().item()
            total += labels.size(0)
        train_acc = 100 * train_accuracy / total
        validation_accuracy, validation_loss = test(cnnNetwork, lossFunction, validationLoader)

        train_accuracy_list.append(train_acc)
        validation_accuracy_list.append(validation_accuracy)

        trainLoss = total_train_loss / len(trainLoader)

        train_loss_list.append(trainLoss)
        validation_loss_list.append(validation_loss)
        if validation_accuracy > best_accuracy:
            best_accuracy = validation_accuracy
            torch.save(cnnNetwork, path)

        print('Epoch: %d Train accuracy: %.3f Validation accuracy: %.3f' % (k + 1, train_acc, validation_accuracy))

    print("Best Validation Accuracy: ", best_accuracy)
    return train_accuracy_list, validation_accuracy_list, train_loss_list, validation_loss_list

# %% [markdown]
# <h5>Plot Function</h5>

# %%
def plot_accuracy_and_loss(tr_acc_, val_acc_, tr_loss_, val_loss_, epoch_):
    plt.plot(range(1, epoch_+1), tr_acc_, label='Training Accuracy')
    plt.plot(val_acc_, label='Validation Accuracy')
    plt.title("Train/Validation Accuracy")

    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.ylim(0, 100)
    plt.legend(loc='upper left')
    plt.show()

    plt.plot(range(1, epoch_+1), tr_loss_, label='Training Loss')
    plt.plot(val_loss_, label='Validation Loss')
    plt.title("Train/Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(loc='upper right')
    plt.show()

# %% [markdown]
# <h3>Resnet50 </h3>

# %% [markdown]
# In neural networks, as the depth of the neural network increases, the vanishing gradient problem arises. The vanishing gradient problem is that when a layer using a specific activation function is added to the neural network, the gradient approaches zero, making it difficult to train the neural network. The vanishing gradient problem has been tried to be solved with the Resnet model. It solves this problem by providing direct transition of gradients between layers through shortcuts. Also, with this solution, overfitting is prevented.

# %% [markdown]
# <img src="./resnet_connection.png" alt="Resnet Connection" style="width:300px;height:200px;">

# %% [markdown]
# There are different Resnet models (Resnet18, Resnet34, Resnet50 etc.). We decided to use pretrained Resnet50 in this project. Resnet50 is a CNN model with 50 layers, trained on ImageNet dataset. The structure of the Resnet model is as follows.

# %% [markdown]
# <img src="./resnet50_architecture.jpg" alt="Resnet Connection" style="width:1000px;height:200px;">

# %% [markdown]
# We tried different batch size and learning rate values for this model. For this model, we got the best validation accuracy when batch size value is 32 and the learning rate value is 0.01 .

# %%
epoch = 100
learning_rate = 0.01

resnet_model = torchvision.models.resnet50(pretrained=True)
for param in resnet_model.parameters():
  param.requires_grad = False


num_features = resnet_model.fc.in_features
resnet_model.fc = nn.Linear(num_features, 8)
resnet_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_conv = optim.SGD(filter(lambda p: p.requires_grad, resnet_model.parameters()), lr= learning_rate, momentum=0.9)
best_resnet_model_path = '/content/drive/MyDrive/BBM469-Project/best_resnet_model.pth'
train_acc, val_acc, train_loss, val_loss = train(resnet_model, epoch, criterion, optimizer_conv, best_resnet_model_path)
plot_accuracy_and_loss(train_acc, val_acc, train_loss, val_loss,epoch)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Epoch: 1 Train accuracy: 72.751 Validation accuracy: 82.392
# Epoch: 2 Train accuracy: 83.200 Validation accuracy: 86.156
# Epoch: 3 Train accuracy: 85.137 Validation accuracy: 88.575
# Epoch: 4 Train accuracy: 86.276 Validation accuracy: 88.575
# Epoch: 5 Train accuracy: 86.446 Validation accuracy: 90.726
# Epoch: 6 Train accuracy: 86.817 Validation accuracy: 84.677
# Epoch: 7 Train accuracy: 89.208 Validation accuracy: 89.651
# Epoch: 8 Train accuracy: 88.639 Validation accuracy: 91.129
# Epoch: 9 Train accuracy: 88.867 Validation accuracy: 90.726
# Epoch: 10 Train accuracy: 88.753 Validation accuracy: 91.129
# Epoch: 11 Train accuracy: 88.269 Validation accuracy: 89.651
# Epoch: 12 Train accuracy: 88.753 Validation accuracy: 92.876
# Epoch: 13 Train accuracy: 88.013 Validation accuracy: 89.651
# Epoch: 14 Train accuracy: 87.842 Validation accuracy: 89.785
# Epoch: 15 Train accuracy: 89.408 Validation accuracy: 90.591
# Epoch: 16 Train accuracy: 88.554 Validation accuracy: 89.919
# Epoch: 17 Train accuracy: 89.636 Validation accuracy: 88.978
# Epoch: 18 Train accuracy: 88.240 Validation accuracy: 89.113
# Epoch: 19 Train accuracy: 89.977 Validation accuracy: 90.860
# Epoch: 20 Train accuracy: 90.205 Validation accuracy: 91.398
# Epoch: 21 Train accuracy: 89.379 Validation accuracy: 90.726
# Epoch: 22 Train accuracy: 88.867 Validation accuracy: 91.801
# Epoch: 23 Train accuracy: 89.493 Validation accuracy: 90.054
# Epoch: 24 Train accuracy: 88.838 Validation accuracy: 90.457
# Epoch: 25 Train accuracy: 89.066 Validation accuracy: 90.995
# Epoch: 26 Train accuracy: 90.319 Validation accuracy: 92.473
# Epoch: 27 Train accuracy: 88.952 Validation accuracy: 90.323
# Epoch: 28 Train accuracy: 90.575 Validation accuracy: 90.860
# Epoch: 29 Train accuracy: 88.610 Validation accuracy: 91.398
# Epoch: 30 Train accuracy: 90.604 Validation accuracy: 91.532
# Epoch: 31 Train accuracy: 90.831 Validation accuracy: 91.667
# Epoch: 32 Train accuracy: 89.493 Validation accuracy: 89.919
# Epoch: 33 Train accuracy: 90.091 Validation accuracy: 91.263
# Epoch: 34 Train accuracy: 90.262 Validation accuracy: 91.667
# Epoch: 35 Train accuracy: 90.689 Validation accuracy: 90.995
# Epoch: 36 Train accuracy: 90.120 Validation accuracy: 91.801
# Epoch: 37 Train accuracy: 90.831 Validation accuracy: 91.801
# Epoch: 38 Train accuracy: 91.059 Validation accuracy: 88.710
# Epoch: 39 Train accuracy: 90.319 Validation accuracy: 91.935
# Epoch: 40 Train accuracy: 90.148 Validation accuracy: 90.726
# Epoch: 41 Train accuracy: 89.806 Validation accuracy: 91.667
# Epoch: 42 Train accuracy: 90.376 Validation accuracy: 90.726
# Epoch: 43 Train accuracy: 90.689 Validation accuracy: 86.425
# Epoch: 44 Train accuracy: 90.774 Validation accuracy: 92.876
# Epoch: 45 Train accuracy: 90.404 Validation accuracy: 91.263
# Epoch: 46 Train accuracy: 90.518 Validation accuracy: 90.591
# Epoch: 47 Train accuracy: 91.315 Validation accuracy: 92.473
# Epoch: 48 Train accuracy: 91.401 Validation accuracy: 91.398
# Epoch: 49 Train accuracy: 90.604 Validation accuracy: 91.801
# Epoch: 50 Train accuracy: 91.686 Validation accuracy: 91.667
# Epoch: 51 Train accuracy: 90.347 Validation accuracy: 91.263
# Epoch: 52 Train accuracy: 89.038 Validation accuracy: 91.532
# Epoch: 53 Train accuracy: 91.714 Validation accuracy: 91.667
# Epoch: 54 Train accuracy: 92.084 Validation accuracy: 91.263
# Epoch: 55 Train accuracy: 90.718 Validation accuracy: 91.935
# Epoch: 56 Train accuracy: 91.372 Validation accuracy: 91.801
# Epoch: 57 Train accuracy: 91.088 Validation accuracy: 91.935
# Epoch: 58 Train accuracy: 90.148 Validation accuracy: 91.398
# Epoch: 59 Train accuracy: 91.743 Validation accuracy: 92.204
# Epoch: 60 Train accuracy: 90.888 Validation accuracy: 91.667
# Epoch: 61 Train accuracy: 92.170 Validation accuracy: 92.204
# Epoch: 62 Train accuracy: 92.967 Validation accuracy: 90.323
# Epoch: 63 Train accuracy: 92.027 Validation accuracy: 89.919
# Epoch: 64 Train accuracy: 91.771 Validation accuracy: 91.263
# Epoch: 65 Train accuracy: 90.774 Validation accuracy: 92.608
# Epoch: 66 Train accuracy: 91.828 Validation accuracy: 91.801
# Epoch: 67 Train accuracy: 91.287 Validation accuracy: 92.070
# Epoch: 68 Train accuracy: 91.686 Validation accuracy: 91.532
# Epoch: 69 Train accuracy: 91.173 Validation accuracy: 91.667
# Epoch: 70 Train accuracy: 90.888 Validation accuracy: 92.608
# Epoch: 71 Train accuracy: 91.970 Validation accuracy: 90.457
# Epoch: 72 Train accuracy: 92.227 Validation accuracy: 92.876
# Epoch: 73 Train accuracy: 92.084 Validation accuracy: 91.398
# Epoch: 74 Train accuracy: 92.084 Validation accuracy: 88.844
# Epoch: 75 Train accuracy: 91.714 Validation accuracy: 91.398
# Epoch: 76 Train accuracy: 92.483 Validation accuracy: 92.473
# Epoch: 77 Train accuracy: 91.856 Validation accuracy: 91.935
# Epoch: 78 Train accuracy: 91.401 Validation accuracy: 90.726
# Epoch: 79 Train accuracy: 92.454 Validation accuracy: 92.608
# Epoch: 80 Train accuracy: 91.088 Validation accuracy: 91.935
# Epoch: 81 Train accuracy: 90.120 Validation accuracy: 90.995
# Epoch: 82 Train accuracy: 90.974 Validation accuracy: 89.113
# Epoch: 83 Train accuracy: 91.344 Validation accuracy: 91.801
# Epoch: 84 Train accuracy: 90.974 Validation accuracy: 91.398
# Epoch: 85 Train accuracy: 91.999 Validation accuracy: 93.280
# Epoch: 86 Train accuracy: 91.657 Validation accuracy: 92.876
# Epoch: 87 Train accuracy: 91.486 Validation accuracy: 91.935
# Epoch: 88 Train accuracy: 92.426 Validation accuracy: 92.608
# Epoch: 89 Train accuracy: 91.828 Validation accuracy: 89.113
# Epoch: 90 Train accuracy: 91.856 Validation accuracy: 91.801
# Epoch: 91 Train accuracy: 92.170 Validation accuracy: 91.667
# Epoch: 92 Train accuracy: 91.515 Validation accuracy: 91.667
# Epoch: 93 Train accuracy: 91.543 Validation accuracy: 92.070
# Epoch: 94 Train accuracy: 91.429 Validation accuracy: 91.935
# Epoch: 95 Train accuracy: 90.604 Validation accuracy: 93.145
# Epoch: 96 Train accuracy: 92.170 Validation accuracy: 92.742
# Epoch: 97 Train accuracy: 92.853 Validation accuracy: 93.145
# Epoch: 98 Train accuracy: 92.454 Validation accuracy: 92.608
# Epoch: 99 Train accuracy: 92.654 Validation accuracy: 92.473
# Epoch: 100 Train accuracy: 92.654 Validation accuracy: 91.667
# Best Validation Accuracy:  93.27956989247312

# %% [markdown]
# <h3>VGG16 </h3>

# %% [markdown]
# VGG16 is a CNN model consisting of small filter sizes, 13 convolution layers and 3 fully connected layers. We used the VGG16 model trained on ImageNet dataset.<br>
# The structure of the VGG16 model is as follows.

# %% [markdown]
# <img src="./vgg16_architecture.png" alt="Resnet Connection" style="width:1000px;height:200px;">

# %% [markdown]
# We tried different batch size and learning rate values for this model. For this model, we got the best validation accuracy when batch size value is 32 and the learning rate value is 0.01 .

# %%
epoch = 100
learning_rate = 0.01

vgg16_model = torchvision.models.vgg16(pretrained=True)
for param in vgg16_model.parameters():
  param.requires_grad = False


num_features = vgg16_model.classifier[6].in_features
vgg16_model.classifier[6] = nn.Linear(num_features, 8)
vgg16_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_conv = optim.SGD(filter(lambda p: p.requires_grad, vgg16_model.parameters()), lr= learning_rate, momentum=0.9)
best_vgg16_model_path = '/content/drive/MyDrive/BBM469-Project/best_vgg16_model.pth'
train_acc, val_acc, train_loss, val_loss = train(vgg16_model, epoch, criterion, optimizer_conv, best_vgg16_model_path)
plot_accuracy_and_loss(train_acc, val_acc, train_loss, val_loss, epoch)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# Epoch: 1 Train accuracy: 65.290 Validation accuracy: 72.043
# Epoch: 2 Train accuracy: 71.071 Validation accuracy: 73.790
# Epoch: 3 Train accuracy: 73.719 Validation accuracy: 77.823
# Epoch: 4 Train accuracy: 72.864 Validation accuracy: 78.898
# Epoch: 5 Train accuracy: 74.146 Validation accuracy: 81.452
# Epoch: 6 Train accuracy: 73.804 Validation accuracy: 75.806
# Epoch: 7 Train accuracy: 74.829 Validation accuracy: 81.586
# Epoch: 8 Train accuracy: 75.598 Validation accuracy: 84.274
# Epoch: 9 Train accuracy: 75.313 Validation accuracy: 82.258
# Epoch: 10 Train accuracy: 75.313 Validation accuracy: 78.360
# Epoch: 11 Train accuracy: 75.171 Validation accuracy: 80.914
# Epoch: 12 Train accuracy: 75.712 Validation accuracy: 81.855
# Epoch: 13 Train accuracy: 76.395 Validation accuracy: 83.065
# Epoch: 14 Train accuracy: 76.082 Validation accuracy: 80.914
# Epoch: 15 Train accuracy: 75.911 Validation accuracy: 83.333
# Epoch: 16 Train accuracy: 76.481 Validation accuracy: 81.989
# Epoch: 17 Train accuracy: 77.249 Validation accuracy: 84.005
# Epoch: 18 Train accuracy: 77.506 Validation accuracy: 82.661
# Epoch: 19 Train accuracy: 77.221 Validation accuracy: 84.677
# Epoch: 20 Train accuracy: 76.481 Validation accuracy: 81.048
# Epoch: 21 Train accuracy: 76.879 Validation accuracy: 83.199
# Epoch: 22 Train accuracy: 76.395 Validation accuracy: 82.527
# Epoch: 23 Train accuracy: 77.563 Validation accuracy: 81.586
# Epoch: 24 Train accuracy: 77.904 Validation accuracy: 82.392
# Epoch: 25 Train accuracy: 77.420 Validation accuracy: 81.586
# Epoch: 26 Train accuracy: 77.933 Validation accuracy: 83.333
# Epoch: 27 Train accuracy: 78.445 Validation accuracy: 83.199
# Epoch: 28 Train accuracy: 77.306 Validation accuracy: 81.048
# Epoch: 29 Train accuracy: 77.477 Validation accuracy: 83.468
# Epoch: 30 Train accuracy: 78.616 Validation accuracy: 82.124
# Epoch: 31 Train accuracy: 76.737 Validation accuracy: 79.301
# Epoch: 32 Train accuracy: 77.990 Validation accuracy: 80.914
# Epoch: 33 Train accuracy: 77.079 Validation accuracy: 79.435
# Epoch: 34 Train accuracy: 77.335 Validation accuracy: 81.720
# Epoch: 35 Train accuracy: 78.502 Validation accuracy: 85.887
# Epoch: 36 Train accuracy: 79.243 Validation accuracy: 86.828
# Epoch: 37 Train accuracy: 77.847 Validation accuracy: 84.677
# Epoch: 38 Train accuracy: 77.705 Validation accuracy: 81.452
# Epoch: 39 Train accuracy: 78.360 Validation accuracy: 84.543
# Epoch: 40 Train accuracy: 77.420 Validation accuracy: 83.333
# Epoch: 41 Train accuracy: 78.104 Validation accuracy: 84.543
# Epoch: 42 Train accuracy: 79.072 Validation accuracy: 83.333
# Epoch: 43 Train accuracy: 79.214 Validation accuracy: 84.274
# Epoch: 44 Train accuracy: 77.961 Validation accuracy: 80.242
# Epoch: 45 Train accuracy: 78.274 Validation accuracy: 84.140
# Epoch: 46 Train accuracy: 78.218 Validation accuracy: 81.452
# Epoch: 47 Train accuracy: 77.563 Validation accuracy: 82.258
# Epoch: 48 Train accuracy: 79.243 Validation accuracy: 84.543
# Epoch: 49 Train accuracy: 77.022 Validation accuracy: 83.602
# Epoch: 50 Train accuracy: 78.445 Validation accuracy: 81.317
# Epoch: 51 Train accuracy: 78.588 Validation accuracy: 84.543
# Epoch: 52 Train accuracy: 78.417 Validation accuracy: 80.376
# Epoch: 53 Train accuracy: 79.015 Validation accuracy: 84.409
# Epoch: 54 Train accuracy: 78.559 Validation accuracy: 80.242
# Epoch: 55 Train accuracy: 79.043 Validation accuracy: 81.989
# Epoch: 56 Train accuracy: 78.702 Validation accuracy: 77.957
# Epoch: 57 Train accuracy: 78.018 Validation accuracy: 84.409
# Epoch: 58 Train accuracy: 78.474 Validation accuracy: 82.796
# Epoch: 59 Train accuracy: 79.385 Validation accuracy: 83.333
# Epoch: 60 Train accuracy: 78.474 Validation accuracy: 84.409
# Epoch: 61 Train accuracy: 77.847 Validation accuracy: 85.081
# Epoch: 62 Train accuracy: 79.157 Validation accuracy: 84.140
# Epoch: 63 Train accuracy: 79.983 Validation accuracy: 85.349
# Epoch: 64 Train accuracy: 78.815 Validation accuracy: 86.828
# Epoch: 65 Train accuracy: 79.584 Validation accuracy: 84.140
# Epoch: 66 Train accuracy: 79.129 Validation accuracy: 84.946
# Epoch: 67 Train accuracy: 79.043 Validation accuracy: 84.946
# Epoch: 68 Train accuracy: 78.901 Validation accuracy: 84.274
# Epoch: 69 Train accuracy: 79.442 Validation accuracy: 87.903
# Epoch: 70 Train accuracy: 79.043 Validation accuracy: 86.425
# Epoch: 71 Train accuracy: 79.470 Validation accuracy: 85.753
# Epoch: 72 Train accuracy: 79.641 Validation accuracy: 85.887
# Epoch: 73 Train accuracy: 79.328 Validation accuracy: 84.005
# Epoch: 74 Train accuracy: 79.356 Validation accuracy: 86.694
# Epoch: 75 Train accuracy: 78.331 Validation accuracy: 85.753
# Epoch: 76 Train accuracy: 79.670 Validation accuracy: 87.769
# Epoch: 77 Train accuracy: 78.445 Validation accuracy: 85.887
# Epoch: 78 Train accuracy: 78.075 Validation accuracy: 86.694
# Epoch: 79 Train accuracy: 78.388 Validation accuracy: 85.215
# Epoch: 80 Train accuracy: 78.986 Validation accuracy: 84.812
# Epoch: 81 Train accuracy: 78.702 Validation accuracy: 82.258
# Epoch: 82 Train accuracy: 78.673 Validation accuracy: 84.812
# Epoch: 83 Train accuracy: 79.271 Validation accuracy: 85.618
# Epoch: 84 Train accuracy: 78.303 Validation accuracy: 82.930
# Epoch: 85 Train accuracy: 78.303 Validation accuracy: 84.409
# Epoch: 86 Train accuracy: 79.043 Validation accuracy: 85.215
# Epoch: 87 Train accuracy: 80.040 Validation accuracy: 87.634
# Epoch: 88 Train accuracy: 78.303 Validation accuracy: 87.231
# Epoch: 89 Train accuracy: 79.186 Validation accuracy: 86.828
# Epoch: 90 Train accuracy: 78.929 Validation accuracy: 83.871
# Epoch: 91 Train accuracy: 78.474 Validation accuracy: 85.618
# Epoch: 92 Train accuracy: 79.784 Validation accuracy: 87.097
# Epoch: 93 Train accuracy: 78.474 Validation accuracy: 84.274
# Epoch: 94 Train accuracy: 78.616 Validation accuracy: 83.871
# Epoch: 95 Train accuracy: 79.670 Validation accuracy: 85.215
# Epoch: 96 Train accuracy: 78.759 Validation accuracy: 86.290
# Epoch: 97 Train accuracy: 79.470 Validation accuracy: 84.677
# Epoch: 98 Train accuracy: 79.243 Validation accuracy: 86.290
# Epoch: 99 Train accuracy: 79.670 Validation accuracy: 85.215
# Epoch: 100 Train accuracy: 78.161 Validation accuracy: 85.349
# Best Validation Accuracy:  87.90322580645162

# %% [markdown]
# <h3>MobileNetV2 </h3>

# %% [markdown]
# MobileNetV2 is a CNN model developed for use in mobile devices. MobileNetV2 is based on an inverted residual block structure for efficiency reasons.<br>
# We used MobileNetV2 model trained on ImageNet dataset.<br>
# The structure of the MobileNetV2 model is as follows.

# %% [markdown]
# <img src="./mobilenet_v2_architecture.png" alt="Resnet Connection" style="width:300px;height:300px;">

# %% [markdown]
# We tried different batch size and learning rate values for this model. For this model, we got the best validation accuracy when batch size value is 32 and the learning rate value is 0.01 .

# %%
epoch = 100
learning_rate = 0.01

mobilenet = models.mobilenet_v2(pretrained=True)
    
for param in mobilenet.parameters():
  param.requires_grad = False

mobilenet.classifier[1] = nn.Linear(1280, 8)
mobilenet.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_conv = optim.SGD(filter(lambda p: p.requires_grad, mobilenet.parameters()), lr= learning_rate, momentum=0.9)
best_mobileNet_model_path = '/content/drive/MyDrive/BBM469-Project/best_mobileNet_model.pth'
tr_acc, val_acc, tr_loss, val_loss = train(mobilenet, epoch, criterion, optimizer_conv, best_mobileNet_model_path)
plot_accuracy_and_loss(tr_acc, val_acc, tr_loss, val_loss,epoch)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# HBox(children=(FloatProgress(value=0.0, max=14212972.0), HTML(value='')))
# Epoch: 1 Train accuracy: 76.509 Validation accuracy: 86.694
# Epoch: 2 Train accuracy: 83.685 Validation accuracy: 84.274
# Epoch: 3 Train accuracy: 85.336 Validation accuracy: 87.097
# Epoch: 4 Train accuracy: 85.222 Validation accuracy: 88.844
# Epoch: 5 Train accuracy: 84.311 Validation accuracy: 85.349
# Epoch: 6 Train accuracy: 86.219 Validation accuracy: 91.129
# Epoch: 7 Train accuracy: 87.101 Validation accuracy: 89.113
# Epoch: 8 Train accuracy: 88.069 Validation accuracy: 88.844
# Epoch: 9 Train accuracy: 87.443 Validation accuracy: 87.769
# Epoch: 10 Train accuracy: 87.984 Validation accuracy: 89.785
# Epoch: 11 Train accuracy: 87.642 Validation accuracy: 88.172
# Epoch: 12 Train accuracy: 88.610 Validation accuracy: 89.247
# Epoch: 13 Train accuracy: 86.589 Validation accuracy: 87.366
# Epoch: 14 Train accuracy: 86.418 Validation accuracy: 90.591
# Epoch: 15 Train accuracy: 88.041 Validation accuracy: 88.038
# Epoch: 16 Train accuracy: 87.215 Validation accuracy: 86.962
# Epoch: 17 Train accuracy: 87.557 Validation accuracy: 88.172
# Epoch: 18 Train accuracy: 86.987 Validation accuracy: 89.785
# Epoch: 19 Train accuracy: 87.472 Validation accuracy: 84.812
# Epoch: 20 Train accuracy: 87.044 Validation accuracy: 91.398
# Epoch: 21 Train accuracy: 87.472 Validation accuracy: 90.323
# Epoch: 22 Train accuracy: 87.614 Validation accuracy: 90.591
# Epoch: 23 Train accuracy: 87.927 Validation accuracy: 90.054
# Epoch: 24 Train accuracy: 88.440 Validation accuracy: 91.263
# Epoch: 25 Train accuracy: 88.013 Validation accuracy: 90.457
# Epoch: 26 Train accuracy: 88.183 Validation accuracy: 91.532
# Epoch: 27 Train accuracy: 87.500 Validation accuracy: 88.978
# Epoch: 28 Train accuracy: 88.354 Validation accuracy: 90.054
# Epoch: 29 Train accuracy: 87.187 Validation accuracy: 89.919
# Epoch: 30 Train accuracy: 88.269 Validation accuracy: 89.516
# Epoch: 31 Train accuracy: 86.703 Validation accuracy: 87.634
# Epoch: 32 Train accuracy: 88.981 Validation accuracy: 91.532
# Epoch: 33 Train accuracy: 87.699 Validation accuracy: 91.532
# Epoch: 34 Train accuracy: 88.383 Validation accuracy: 90.457
# Epoch: 35 Train accuracy: 88.126 Validation accuracy: 91.263
# Epoch: 36 Train accuracy: 89.237 Validation accuracy: 88.038
# Epoch: 37 Train accuracy: 88.383 Validation accuracy: 87.903
# Epoch: 38 Train accuracy: 87.500 Validation accuracy: 88.710
# Epoch: 39 Train accuracy: 87.557 Validation accuracy: 87.634
# Epoch: 40 Train accuracy: 88.183 Validation accuracy: 89.516
# Epoch: 41 Train accuracy: 87.842 Validation accuracy: 90.054
# Epoch: 42 Train accuracy: 88.867 Validation accuracy: 90.457
# Epoch: 43 Train accuracy: 87.699 Validation accuracy: 87.903
# Epoch: 44 Train accuracy: 88.183 Validation accuracy: 90.457
# Epoch: 45 Train accuracy: 87.443 Validation accuracy: 88.575
# Epoch: 46 Train accuracy: 88.183 Validation accuracy: 90.860
# Epoch: 47 Train accuracy: 87.671 Validation accuracy: 90.860
# Epoch: 48 Train accuracy: 87.984 Validation accuracy: 89.516
# Epoch: 49 Train accuracy: 88.240 Validation accuracy: 90.860
# Epoch: 50 Train accuracy: 87.984 Validation accuracy: 90.726
# Epoch: 51 Train accuracy: 88.468 Validation accuracy: 91.129
# Epoch: 52 Train accuracy: 88.326 Validation accuracy: 89.919
# Epoch: 53 Train accuracy: 87.813 Validation accuracy: 90.054
# Epoch: 54 Train accuracy: 87.956 Validation accuracy: 89.651
# Epoch: 55 Train accuracy: 87.187 Validation accuracy: 89.919
# Epoch: 56 Train accuracy: 88.781 Validation accuracy: 91.263
# Epoch: 57 Train accuracy: 88.240 Validation accuracy: 89.919
# Epoch: 58 Train accuracy: 87.728 Validation accuracy: 90.457
# Epoch: 59 Train accuracy: 88.354 Validation accuracy: 90.054
# Epoch: 60 Train accuracy: 88.781 Validation accuracy: 90.323
# Epoch: 61 Train accuracy: 88.411 Validation accuracy: 86.425
# Epoch: 62 Train accuracy: 88.440 Validation accuracy: 90.591
# Epoch: 63 Train accuracy: 88.838 Validation accuracy: 90.995
# Epoch: 64 Train accuracy: 88.610 Validation accuracy: 90.323
# Epoch: 65 Train accuracy: 88.411 Validation accuracy: 90.323
# Epoch: 66 Train accuracy: 87.272 Validation accuracy: 90.591
# Epoch: 67 Train accuracy: 89.322 Validation accuracy: 91.129
# Epoch: 68 Train accuracy: 88.411 Validation accuracy: 90.591
# Epoch: 69 Train accuracy: 88.696 Validation accuracy: 89.651
# Epoch: 70 Train accuracy: 89.493 Validation accuracy: 90.995
# Epoch: 71 Train accuracy: 88.183 Validation accuracy: 90.591
# Epoch: 72 Train accuracy: 87.699 Validation accuracy: 91.263
# Epoch: 73 Train accuracy: 88.554 Validation accuracy: 90.323
# Epoch: 74 Train accuracy: 88.212 Validation accuracy: 87.903
# Epoch: 75 Train accuracy: 87.472 Validation accuracy: 90.860
# Epoch: 76 Train accuracy: 88.126 Validation accuracy: 89.382
# Epoch: 77 Train accuracy: 88.952 Validation accuracy: 88.978
# Epoch: 78 Train accuracy: 89.208 Validation accuracy: 88.844
# Epoch: 79 Train accuracy: 88.098 Validation accuracy: 90.054
# Epoch: 80 Train accuracy: 88.582 Validation accuracy: 88.575
# Epoch: 81 Train accuracy: 87.215 Validation accuracy: 88.978
# Epoch: 82 Train accuracy: 87.756 Validation accuracy: 87.903
# Epoch: 83 Train accuracy: 87.187 Validation accuracy: 91.667
# Epoch: 84 Train accuracy: 88.269 Validation accuracy: 89.785
# Epoch: 85 Train accuracy: 87.642 Validation accuracy: 90.995
# Epoch: 86 Train accuracy: 88.554 Validation accuracy: 91.263
# Epoch: 87 Train accuracy: 89.038 Validation accuracy: 90.188
# Epoch: 88 Train accuracy: 88.183 Validation accuracy: 90.860
# Epoch: 89 Train accuracy: 88.354 Validation accuracy: 90.726
# Epoch: 90 Train accuracy: 88.155 Validation accuracy: 90.726
# Epoch: 91 Train accuracy: 88.724 Validation accuracy: 88.172
# Epoch: 92 Train accuracy: 88.098 Validation accuracy: 89.785
# Epoch: 93 Train accuracy: 89.066 Validation accuracy: 91.532
# Epoch: 94 Train accuracy: 88.013 Validation accuracy: 88.575
# Epoch: 95 Train accuracy: 87.785 Validation accuracy: 90.591
# Epoch: 96 Train accuracy: 88.013 Validation accuracy: 90.726
# Epoch: 97 Train accuracy: 87.927 Validation accuracy: 90.323
# Epoch: 98 Train accuracy: 88.895 Validation accuracy: 90.457
# Epoch: 99 Train accuracy: 88.468 Validation accuracy: 90.726
# Epoch: 100 Train accuracy: 88.952 Validation accuracy: 90.457
# Best Validation Accuracy:  91.66666666666667

# %% [markdown]
# <h3>EfficientNet </h3>

# %% [markdown]
# EfficientNet is a CNN model that equally scales all depth, width, and resolution dimensions using a compound coefficient. EfficientNet consists of 8 different models between EfficientNet B0 and B7. While moving from B0 to B7, the number of parameters calculated and accuracy increases.
# We used the pre-trained EfficentNet B3 model in our project.

# %% [markdown]
# <img src="./efficientNetComparison.png" alt="Resnet Connection" style="width:500px;height:400px;">

# %% [markdown]
# We tried different batch size and learning rate values for this model. For this model, we got the best validation accuracy when batch size value is 32 and the learning rate value is 0.001 .

# %%
epoch = 100
learning_rate = 0.001

# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet
efficientnet_model = EfficientNet.from_pretrained('efficientnet-b3', num_classes=8)


efficientnet_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_conv = optim.SGD(filter(lambda p: p.requires_grad, efficientnet_model.parameters()), lr= learning_rate, momentum=0.9)
best_efficientNet_model_path = '/content/drive/MyDrive/BBM469-Project/best_efficientNet_model.pth'
tr_acc, val_acc, tr_loss, val_loss = train(efficientnet_model, epoch, criterion, optimizer_conv, best_efficientNet_model_path)
plot_accuracy_and_loss(tr_acc, val_acc, tr_loss, val_loss,epoch)
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/2e/a0/dd40b50aebf0028054b6b35062948da01123d7be38d08b6b1e5435df6363/efficientnet_pytorch-0.7.1.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=f1fd0ec919bbe59bf9daae511a523eae6ad5812ce539fb43d557d4f441cd9133
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b3-5fb5a3c3.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b3-5fb5a3c3.pth
# HBox(children=(FloatProgress(value=0.0, max=49388949.0), HTML(value='')))
# Loaded pretrained weights for efficientnet-b3
# Epoch: 1 Train accuracy: 56.293 Validation accuracy: 77.957
# Epoch: 2 Train accuracy: 80.040 Validation accuracy: 84.140
# Epoch: 3 Train accuracy: 85.792 Validation accuracy: 88.038
# Epoch: 4 Train accuracy: 88.440 Validation accuracy: 88.172
# Epoch: 5 Train accuracy: 88.554 Validation accuracy: 88.978
# Epoch: 6 Train accuracy: 90.091 Validation accuracy: 89.651
# Epoch: 7 Train accuracy: 90.689 Validation accuracy: 90.860
# Epoch: 8 Train accuracy: 91.714 Validation accuracy: 91.263
# Epoch: 9 Train accuracy: 92.170 Validation accuracy: 92.204
# Epoch: 10 Train accuracy: 93.451 Validation accuracy: 91.801
# Epoch: 11 Train accuracy: 93.109 Validation accuracy: 92.608
# Epoch: 12 Train accuracy: 93.650 Validation accuracy: 92.473
# Epoch: 13 Train accuracy: 94.248 Validation accuracy: 92.876
# Epoch: 14 Train accuracy: 93.964 Validation accuracy: 93.683
# Epoch: 15 Train accuracy: 94.049 Validation accuracy: 94.086
# Epoch: 16 Train accuracy: 94.106 Validation accuracy: 94.086
# Epoch: 17 Train accuracy: 95.131 Validation accuracy: 94.624
# Epoch: 18 Train accuracy: 94.761 Validation accuracy: 94.220
# Epoch: 19 Train accuracy: 95.672 Validation accuracy: 94.220
# Epoch: 20 Train accuracy: 95.530 Validation accuracy: 95.027
# Epoch: 21 Train accuracy: 95.757 Validation accuracy: 94.892
# Epoch: 22 Train accuracy: 96.213 Validation accuracy: 95.027
# Epoch: 23 Train accuracy: 95.900 Validation accuracy: 95.430
# Epoch: 24 Train accuracy: 95.615 Validation accuracy: 95.027
# Epoch: 25 Train accuracy: 96.555 Validation accuracy: 95.699
# Epoch: 26 Train accuracy: 96.185 Validation accuracy: 95.161
# Epoch: 27 Train accuracy: 96.896 Validation accuracy: 95.296
# Epoch: 28 Train accuracy: 97.295 Validation accuracy: 94.892
# Epoch: 29 Train accuracy: 97.210 Validation accuracy: 95.430
# Epoch: 30 Train accuracy: 97.124 Validation accuracy: 95.565
# Epoch: 31 Train accuracy: 97.694 Validation accuracy: 95.161
# Epoch: 32 Train accuracy: 97.494 Validation accuracy: 95.430
# Epoch: 33 Train accuracy: 97.694 Validation accuracy: 94.892
# Epoch: 34 Train accuracy: 97.466 Validation accuracy: 95.565
# Epoch: 35 Train accuracy: 97.153 Validation accuracy: 95.430
# Epoch: 36 Train accuracy: 97.836 Validation accuracy: 95.565
# Epoch: 37 Train accuracy: 97.637 Validation accuracy: 95.699
# Epoch: 38 Train accuracy: 97.466 Validation accuracy: 95.565
# Epoch: 39 Train accuracy: 98.149 Validation accuracy: 95.833
# Epoch: 40 Train accuracy: 98.149 Validation accuracy: 95.296
# Epoch: 41 Train accuracy: 97.437 Validation accuracy: 95.699
# Epoch: 42 Train accuracy: 98.007 Validation accuracy: 95.565
# Epoch: 43 Train accuracy: 98.320 Validation accuracy: 95.161
# Epoch: 44 Train accuracy: 98.434 Validation accuracy: 95.565
# Epoch: 45 Train accuracy: 98.178 Validation accuracy: 96.102
# Epoch: 46 Train accuracy: 98.320 Validation accuracy: 95.968
# Epoch: 47 Train accuracy: 98.292 Validation accuracy: 95.430
# Epoch: 48 Train accuracy: 98.092 Validation accuracy: 95.833
# Epoch: 49 Train accuracy: 98.405 Validation accuracy: 96.102
# Epoch: 50 Train accuracy: 98.462 Validation accuracy: 96.102
# Epoch: 51 Train accuracy: 98.519 Validation accuracy: 96.774
# Epoch: 52 Train accuracy: 98.605 Validation accuracy: 96.237
# Epoch: 53 Train accuracy: 98.918 Validation accuracy: 95.968
# Epoch: 54 Train accuracy: 98.633 Validation accuracy: 95.699
# Epoch: 55 Train accuracy: 98.861 Validation accuracy: 95.699
# Epoch: 56 Train accuracy: 98.576 Validation accuracy: 95.968
# Epoch: 57 Train accuracy: 98.804 Validation accuracy: 96.371
# Epoch: 58 Train accuracy: 98.975 Validation accuracy: 95.968
# Epoch: 59 Train accuracy: 98.747 Validation accuracy: 96.640
# Epoch: 60 Train accuracy: 98.975 Validation accuracy: 96.237
# Epoch: 61 Train accuracy: 98.946 Validation accuracy: 95.699
# Epoch: 62 Train accuracy: 98.975 Validation accuracy: 96.237
# Epoch: 63 Train accuracy: 98.747 Validation accuracy: 95.968
# Epoch: 64 Train accuracy: 99.174 Validation accuracy: 95.833
# Epoch: 65 Train accuracy: 99.146 Validation accuracy: 96.371
# Epoch: 66 Train accuracy: 99.089 Validation accuracy: 96.102
# Epoch: 67 Train accuracy: 99.003 Validation accuracy: 95.699
# Epoch: 68 Train accuracy: 98.690 Validation accuracy: 95.968
# Epoch: 69 Train accuracy: 99.089 Validation accuracy: 95.833
# Epoch: 70 Train accuracy: 98.975 Validation accuracy: 96.237
# Epoch: 71 Train accuracy: 99.260 Validation accuracy: 96.102
# Epoch: 72 Train accuracy: 98.946 Validation accuracy: 95.833
# Epoch: 73 Train accuracy: 99.089 Validation accuracy: 95.968
# Epoch: 74 Train accuracy: 99.231 Validation accuracy: 95.833
# Epoch: 75 Train accuracy: 99.487 Validation accuracy: 95.833
# Epoch: 76 Train accuracy: 99.089 Validation accuracy: 96.102
# Epoch: 77 Train accuracy: 99.117 Validation accuracy: 96.102
# Epoch: 78 Train accuracy: 99.260 Validation accuracy: 95.968
# Epoch: 79 Train accuracy: 99.402 Validation accuracy: 95.833
# Epoch: 80 Train accuracy: 99.317 Validation accuracy: 96.237
# Epoch: 81 Train accuracy: 99.231 Validation accuracy: 96.102
# Epoch: 82 Train accuracy: 99.317 Validation accuracy: 95.968
# Epoch: 83 Train accuracy: 99.231 Validation accuracy: 96.102
# Epoch: 84 Train accuracy: 99.345 Validation accuracy: 96.102
# Epoch: 85 Train accuracy: 99.544 Validation accuracy: 96.505
# Epoch: 86 Train accuracy: 99.487 Validation accuracy: 96.237
# Epoch: 87 Train accuracy: 99.174 Validation accuracy: 95.968
# Epoch: 88 Train accuracy: 99.516 Validation accuracy: 96.237
# Epoch: 89 Train accuracy: 99.345 Validation accuracy: 96.237
# Epoch: 90 Train accuracy: 99.630 Validation accuracy: 95.968
# Epoch: 91 Train accuracy: 99.573 Validation accuracy: 96.505
# Epoch: 92 Train accuracy: 99.487 Validation accuracy: 96.102
# Epoch: 93 Train accuracy: 99.431 Validation accuracy: 95.968
# Epoch: 94 Train accuracy: 99.487 Validation accuracy: 95.833
# Epoch: 95 Train accuracy: 99.431 Validation accuracy: 95.968
# Epoch: 96 Train accuracy: 99.374 Validation accuracy: 96.505
# Epoch: 97 Train accuracy: 99.345 Validation accuracy: 96.102
# Epoch: 98 Train accuracy: 99.345 Validation accuracy: 96.640
# Epoch: 99 Train accuracy: 99.516 Validation accuracy: 96.237
# Epoch: 100 Train accuracy: 99.459 Validation accuracy: 95.968
# Best Validation Accuracy:  96.7741935483871

# %% [markdown]
# ## Evaluation<a class="anchor" id="evaluation"></a>

# %% [markdown]
# While training the models we used, we saved the models with the highest validation accuracy. We tested the models we saved using the test dataset. We printed test accuracy and we plotted confusion matrix for each model. We calculated the accuracy using the ratio of correct predictions to total predictions. Finally, we compared the test accuracies we obtained using the graph we plotted.

# %% [markdown]
# <h5>Test Function</h5>

# %%
def test_data(cnnNetwork, loader):
  with torch.no_grad():
      cnnNetwork.eval()
      correct = 0.0
      total = 0.0
      conf_matrix_label = []
      conf_matrix_predict = []
      for i, (images, labels) in enumerate(loader):
          images, labels = images.to(device), labels.to(device)
          outputs = cnnNetwork(images)
          
          _, prediction = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (prediction == labels).sum().item()
          
          outputs = (torch.max(torch.exp(outputs), 1)[1]).data.cpu().numpy()
          conf_matrix_predict.extend(outputs)  # Save Prediction
          labels = labels.data.cpu().numpy()
          conf_matrix_label.extend(labels)  # Save Truth

      accuracy = 100 * correct / total
      print("Test accuracy: ", accuracy)
      fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(13, 10))
      class_names = ['TUMOR', 'STROMA', 'COMPLEX', 'LYMPHO', 'DEBRIS', 'MUCOSA', 'ADIPOSE', 'EMPTY']
      axes.set_title('Best Model Confusion Matrix', fontsize=20)
      cm = confusion_matrix(conf_matrix_label, conf_matrix_predict)
      sns.heatmap(cm, annot=True, fmt='g', ax=axes)
      axes.xaxis.set_ticklabels(class_names)
      axes.yaxis.set_ticklabels(class_names)
      plt.show()
      return accuracy

test_accuracies = []

# %% [markdown]
# <h4>Resnet50 Test Results</h4>

# %%
best_resnet_model_path = '/content/drive/MyDrive/BBM469-Project/best_resnet_model.pth'
best_vgg16_model_path = '/content/drive/MyDrive/BBM469-Project/best_vgg16_model.pth'
best_mobileNet_model_path = '/content/drive/MyDrive/BBM469-Project/best_mobileNet_model.pth'

# %%
model = torch.load(best_resnet_model_path)
acc_resnet = test_data(model, testLoader)
test_accuracies.append(acc_resnet)
# Out:
# Test accuracy:  91.61028416779432

# %% [markdown]
# <h4>VGG16 Test Results</h4>

# %%
model = torch.load(best_vgg16_model_path)
acc_vgg = test_data(model, testLoader)
test_accuracies.append(acc_vgg)
# Out:
# Test accuracy:  88.09201623815967

# %% [markdown]
# <h4>MobileNetV2 Test Results</h4>

# %%
model = torch.load(best_mobileNet_model_path)
acc_mobileNet =test_data(model, testLoader)
test_accuracies.append(acc_mobileNet)
# Out:
# Test accuracy:  92.01623815967524

# %% [markdown]
# <h4>EfficientNet Test Results</h4>

# %%
model = torch.load(best_efficientNet_model_path)
acc_efficientNet = test_data(model, testLoader)
test_accuracies.append(acc_efficientNet)
# Out:
# Test accuracy:  96.07577807848443

# %% [markdown]
# <h4>Model Comparison</h4>

# %%
fig = plt.figure(figsize= (6,5))
ax = fig.add_axes([0,0,1,1])
ax.set_title('Test Accuracy Comparison')

classification_methods = ['Resnet50', 'VGG16', 'mobileNet', 'EfficientNet']
ax.bar(classification_methods, test_accuracies)
ax.set(ylim=[80, 100])
ax.set_xlabel("CNN Models")
ax.set_ylabel("Accuracy")
plt.show()

# %%
for i in range(len(test_accuracies)):
  print(" Test Accuracy of " + classification_methods[i]+ " Model:", str(round(test_accuracies[i],3)) + '%'  )
# Out:
#  Test Accuracy of Resnet50 Model: 91.61%
#  Test Accuracy of VGG16 Model: 88.092%
#  Test Accuracy of mobileNet Model: 92.016%
#  Test Accuracy of EfficientNet Model: 96.076%

# %% [markdown]
# According to the results we obtained, we got the best test accuracy in the EfficientNet-B3 model. The results we have obtained are compatible with the graph you see below.

# %% [markdown]
# <img src="./efficientNetComparison.png" alt="Resnet Connection" style="width:500px;height:400px;">

# %% [markdown]
# ## References<a class="anchor" id="references"></a>

# %% [markdown]
# - https://www.kaggle.com/kmader/colorectal-histology-mnist
# - https://cv-tricks.com/keras/understand-implement-resnets/
# - https://pytorch.org/hub/pytorch_vision_mobilenet_v2/
# - https://kgptalkie.com/image-classification-using-pre-trained-vgg-16-model/
# - Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun. Deep Residual Learning for Image Recognition - -(https://arxiv.org/pdf/1512.03385.pdf)
# - Mark Sandler, Andrew Howard, Menglong Zhu, Andrey Zhmoginov, Liang-Chieh Chen. MobileNetV2: Inverted Residuals and Linear Bottlenecks(https://arxiv.org/pdf/1801.04381v4.pdf)
# - Mingxing Tan, Quoc V. Le . EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks (https://arxiv.org/pdf/1905.11946.pdf)
# - https://github.com/lukemelas/EfficientNet-PyTorch
# - https://pytorch.org/hub/pytorch_vision_resnet/
# - https://towardsdatascience.com/the-vanishing-gradient-problem-69bf08b15484
# - https://paperswithcode.com/method/residual-connection
# - https://paperswithcode.com/method/efficientnet

# %% [markdown]
# **Disclaimer!** <font color='grey'>This notebook was prepared by Gökay Berkem TURAN and Zafer Can YÜCEL as a term project for the *BBM469 - Data Intensive Applications Laboratory* class. The notebook is available for educational purposes only. There is no guarantee on the correctness of the content provided as it is a student work.
#
# If you think there is any copyright violation, please let us [know](https://forms.gle/BNNRB2kR8ZHVEREq8).
# </font>
